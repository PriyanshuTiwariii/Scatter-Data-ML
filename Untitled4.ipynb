# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyanshuTiwariii/Scatter-Data-ML/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SEABORN**

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6]
y=[12,2,3,43,21,22]

plt.scatter(x,y,marker="*")
plt.title("Scatter Graph")
plt.xlabel("NO.s")
plt.ylabel("Drinking water in ltrs")
# Out:
# Text(0, 0.5, 'Drinking water in ltrs')
